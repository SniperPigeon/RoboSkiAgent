# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open('../result/plan-gen_20260422_132515_qwen3-8b.csv') as f:
    data = pd.read_csv(f)

model = data['model'][0]
model = [model,"claude-sonnet-4-6"]
avg = [data['score'].mean(),1]
avg
plt.xlabel('Model')
plt.ylabel('Average Score')
plt.title('Plan Generation Average Score Comparison (Sonnet as Ground Truth)') 
plt.bar(model, avg)
# Out:
# <BarContainer object of 2 artists>
