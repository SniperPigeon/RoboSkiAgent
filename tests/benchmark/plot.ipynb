# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open('../result/plan-gen_20260422_132515_qwen3-8b.csv') as f:
    data = pd.read_csv(f)

model = data['model'][0]
model
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 with open('result/plan-gen_20260422_132515_qwen3-8b.csv') as f:
#       2     data = pd.read_csv(f)
#       3
#       4 model = data['model'][0]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'result/plan-gen_20260422_132515_qwen3-8b.csv'
